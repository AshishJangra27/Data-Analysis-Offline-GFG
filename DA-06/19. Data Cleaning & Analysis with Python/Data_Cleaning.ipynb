# %%
import numpy as np
import pandas as pd

# %%
# !git clone https://github.com/AshishJangra27/datasets
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 328, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 328 (delta 19), reused 54 (delta 9), pack-reused 235 (from 1)
# Receiving objects: 100% (328/328), 278.62 MiB | 13.70 MiB/s, done.
# Resolving deltas: 100% (145/145), done.
# Updating files: 100% (225/225), done.

# %%
df = pd.read_csv('/content/datasets/Gaana/songs.csv')

df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                       /unke-dekhe-se     Urdu
# ...

# %%
df = df.drop_duplicates(subset = ['link'])
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df['duration'][:10]
# Out:
# 0    05:00
# 1    06:26
# 2    03:41
# 3    04:26
# 4    05:39
# 5    07:59
# 6    04:48
# 7    05:21
# 8    03:09
# 9    04:24
# Name: duration, dtype: object

# %%
durations = []

for duration in df['duration']:

  if len(duration.split(':')) == 2:

    mint = int(duration.split(':')[0])
    sec  = int(duration.split(':')[1])

    durations.append(mint * 60 + sec)

  else:

    hour = int(duration.split(':')[0])
    mint = int(duration.split(':')[1])
    sec  = int(duration.split(':')[2])

    durations.append(hour * 3600 + mint * 60 + sec)

df['duration_in_sec'] = durations

df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df['singer']
# Out:
# 0             Chitra Singh|Jagjit Singh
# 1             Chitra Singh|Jagjit Singh
# 2                          Jagjit Singh
# 3                          Chitra Singh
# 4                          Jagjit Singh
#                       ...
# 41350                     Kishore Kumar
# 41351                      Feroza Begum
# 41352    Sandhya Mukherjee|Hemant Kumar
# 41353                  Ajoy Chakrabarty
# 41354                       Asha Bhosle
# Name: singer, Length: 36361, dtype: object

# %%
df['singer'].value_counts()
# Out:
# singer
# S. P. Balasubrahmanyam         1151
# Asha Bhosle                    1037
# P. Susheela                    1019
# Lata Mangeshkar                 856
# S. Janaki                       728
#                                ...
# T.R. Mahalingam|P. Susheela       1
# Asha Bhosle|Shashi Kapoor         1
# Sasi Rekha|Ilaiyaraaja            1
# Anu Malik|Udit Narayan            1
# Rabindranath Tagore               1
# Name: count, Length: 6196, dtype: int64

# %%
singers = []

for singer in df['singer'].unique():
  singers += singer.split('|')

singers = list(set(singers))
print(len(singers))
# Out:
# 3940

# %%
from tqdm import tqdm

song_freq = []

for singer in tqdm(singers):
  c = 0
  for i in df['singer']:
    if singer in (i.split('|')):
      c += 1

  song_freq.append([singer,c])
# Out:
# 100%|██████████| 3940/3940 [01:00<00:00, 65.58it/s]

# %%
song_freq = pd.DataFrame(song_freq, columns = ['singer', 'freq'])

song_freq.sort_values(by = 'freq', ascending = False)
# Out:
#                                       singer  freq
# 862                   S. P. Balasubrahmanyam  3613
# 773                              P. Susheela  3212
# 267                                S. Janaki  2193
# 2232                             Asha Bhosle  1981
# 2343                         Lata Mangeshkar  1726
# ...                                      ...   ...
# 1842                             Thyagarajan     1
# 1841  Male Uttar Pradesh singers from Konain     1
# 1838                             Chandervati     1
# 1835                      Amir Chand Shekhar     1
# 3939                              Raveendran     1
#
# [3940 rows x 2 columns]

# %%
df[df['duration_in_sec'] == 25680]
# Out:
#              name          singer               singer_id  duration  \
# 16093  Haye Tumba  Dilshad Akhtar  /artist/dilshad-akhtar  07:08:00
#
#               link language  duration_in_sec
# 16093  /haye-tumba  Punjabi            25680

# %%
df = pd.read_csv('/content/datasets/Job Postings/jobs.csv.zip')

df.head()
# Out:
#          job_id                                           job_role    company  \
# 0  7.012301e+10      Branch Banking - Calling For Women Candidates  Hdfc Bank
# 1  6.012391e+10                       Product Owner Senior Manager  Accenture
# 2  6.012391e+10  Employee Relations and Policies Associate Manager  Accenture
# 3  6.012391e+10         Employee Relations and Policies Specialist  Accenture
# 4  6.012301e+10                                  SAP BO Consultant   Mindtree
#
#   experience         salary  \
# 0    1-6 Yrs  Not disclosed
# 1  11-15 Yrs  Not disclosed
# 2    3-7 Yrs  Not disclosed
# 3    3-7 Yrs  Not disclosed
# 4    5-7 Yrs  Not disclosed
#
#                                             location  rating        reviews  \
# 0  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...     4.0  39110 Reviews
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
# 2  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
# ...

# %%
df.isnull().sum()
# Out:
# job_id               480
# job_role             480
# company              481
# experience          1749
# salary               480
# location            1706
# rating             36199
# reviews            36199
# resposibilities      500
# posted_on            480
# job_link             480
# company_link         480
# dtype: int64

# %%
len(df)
# Out:
# 79147

# %%
df = df.dropna(subset = ['job_id','experience','resposibilities','company'])

len(df)
# Out:
# 77378

# %%
df.isnull().sum()
# Out:
# job_id             0
# job_role           0
# company            0
# experience         0
# salary             0
# location           0
# rating             0
# reviews            0
# resposibilities    0
# posted_on          0
# job_link           0
# company_link       0
# dtype: int64

# %%
df['reviews'] = df['reviews'].fillna('0 Reviews')
df['rating'] = df['rating'].fillna(0)

df.head()
# Out:
#          job_id                                           job_role    company  \
# 0  7.012301e+10      Branch Banking - Calling For Women Candidates  Hdfc Bank
# 1  6.012391e+10                       Product Owner Senior Manager  Accenture
# 2  6.012391e+10  Employee Relations and Policies Associate Manager  Accenture
# 3  6.012391e+10         Employee Relations and Policies Specialist  Accenture
# 4  6.012301e+10                                  SAP BO Consultant   Mindtree
#
#   experience         salary  \
# 0    1-6 Yrs  Not disclosed
# 1  11-15 Yrs  Not disclosed
# 2    3-7 Yrs  Not disclosed
# 3    3-7 Yrs  Not disclosed
# 4    5-7 Yrs  Not disclosed
#
#                                             location  rating        reviews  \
# 0  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...     4.0  39110 Reviews
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
# 2  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
# ...

# %%
df['reviews'] = df['reviews'].str.split(' ').str[0].astype(int)

df.head()
# Out:
#          job_id                                           job_role    company  \
# 0  7.012301e+10      Branch Banking - Calling For Women Candidates  Hdfc Bank
# 1  6.012391e+10                       Product Owner Senior Manager  Accenture
# 2  6.012391e+10  Employee Relations and Policies Associate Manager  Accenture
# 3  6.012391e+10         Employee Relations and Policies Specialist  Accenture
# 4  6.012301e+10                                  SAP BO Consultant   Mindtree
#
#   experience         salary  \
# 0    1-6 Yrs  Not disclosed
# 1  11-15 Yrs  Not disclosed
# 2    3-7 Yrs  Not disclosed
# 3    3-7 Yrs  Not disclosed
# 4    5-7 Yrs  Not disclosed
#
#                                             location  rating  reviews  \
# 0  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...     4.0    39110
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1    32129
# 2  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1    32129
# ...

# %%
df['job_id'] = df['job_id'].astype(int).astype(str)

df
# Out:
#                job_id                                           job_role  \
# 0       70123006070.0      Branch Banking - Calling For Women Candidates
# 1       60123905908.0                       Product Owner Senior Manager
# 2       60123905898.0  Employee Relations and Policies Associate Manager
# 3       60123905897.0         Employee Relations and Policies Specialist
# 4       60123008332.0                                  SAP BO Consultant
# ...               ...                                                ...
# 79142   60123006615.0                           .Net Fullstack Developer
# 79143   11222009693.0        Senior (BI) Business Intelligence Architect
# 79144  151222006599.0                                  PowerBI Developer
# 79145  271222005611.0                         Customer Service Associate
# 79146  211222006941.0                   Senior Java BED ( PAN India)- KG
#
#                      company experience                     salary  \
# ...

# %%
df['rating'].mean()
# Out:
# 2.1386195042518543

# %%
df[df['reviews'] != 0]['reviews'].mean()
# Out:
# 6358.439788455583

# %%
df['reviews'].mean()
# Out:
# 3449.40715707307
