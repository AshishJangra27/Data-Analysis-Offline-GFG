# %%
# !git clone https://github.com/AshishJangra27/datasets

# %% [markdown]
# # Agenda | Top 10 Airbnbs of Manali under 5000
#
# 1. Rating
# 2. Amenities
# 3. Reviews

# %% [markdown]
# ### 1. Exploratory Data Analysis

# %%
import pandas as pd

data = pd.read_csv('/content/datasets/Airbnb/airbnb_v2.csv')
data.head()
# Out:
#    Unnamed: 0        id                                               name  \
# 0           0  49849504                                     Perla bungalov
# 1           1  50891766  Authentic Beach Architect Sheltered Villa with...
# 2           2  50699164                                  cottages sataplia
# 3           3  49871422                        Sapanca Breathable Bungalow
# 4           4  51245886                                      Bungalov Ev 2
#
#   rating reviews    host_name      host_id                   address  \
# 0   4.71      64    Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1    New       0        Fatih  386223873.0      Kaş, Antalya, Turkey
# 2   4.85      68       Giorgi  409690853.0          Imereti, Georgia
# 3    5.0      13        Melih  401873242.0  Sapanca, Sakarya, Turkey
# 4    New       0  Arp Sapanca  414884116.0  Sapanca, Sakarya, Turkey
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# 1  4 guests,2 bedrooms,2 beds,2 bathrooms
# 2    4 guests,1 bedroom,3 beds,1 bathroom
# 3    4 guests,1 bedroom,2 beds,1 bathroom
# 4     2 guests,1 bedroom,1 bed,1 bathroom
#
#                                            amenities  ...  price   country  \
# 0  Mountain view,Valley view,Lake access,Kitchen,...  ...   8078    Turkey
# 1  Kitchen,Wifi,Dedicated workspace,Free parking ...  ...   4665    Turkey
# 2  Mountain view,Kitchen,Wifi,Dedicated workspace...  ...   5991   Georgia
# 3  Mountain view,Valley view,Kitchen,Wifi,Free pa...  ...  11339    Turkey
# 4  Kitchen,Wifi,Free parking on premises,TV,Air c...  ...   6673    Turkey
#
#   bathrooms  beds guests  toiles  bedrooms  studios              checkin  \
# 0         1     1      2       0         2        0             Flexible
# 1         2     2      4       0         2        0   4 00 pm - 11 00 pm
# 2         1     3      4       0         1        0        After 1 00 pm
# 3         1     2      4       0         1        0        After 2 00 pm
# 4         1     1      2       0         1        0        After 2 00 pm
#
#     checkout
# 0   12 00 pm
# 1   10 00 am
# 2   12 00 pm
# 3   12 00 pm
# 4   12 00 pm
#
# [5 rows x 23 columns]

# %% [markdown]
# #### 1.1) Checking basic detials

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12805 entries, 0 to 12804
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    12805 non-null  int64
#  1   id            12805 non-null  int64
#  2   name          12805 non-null  object
#  3   rating        12805 non-null  object
#  4   reviews       12805 non-null  object
#  5   host_name     12797 non-null  object
#  6   host_id       12805 non-null  float64
#  7   address       12805 non-null  object
#  8   features      12805 non-null  object
#  9   amenities     12805 non-null  object
#  10  safety_rules  12805 non-null  object
#  11  hourse_rules  12805 non-null  object
#  12  img_links     12805 non-null  object
#  13  price         12805 non-null  int64
#  14  country       12805 non-null  object
#  15  bathrooms     12805 non-null  int64
#  16  beds          12805 non-null  int64
#  17  guests        12805 non-null  int64
#  18  toiles        12805 non-null  int64
#  19  bedrooms      12805 non-null  int64
#  20  studios       12805 non-null  int64
#  21  checkin       12005 non-null  object
#  22  checkout      10355 non-null  object
# dtypes: float64(1), int64(9), object(13)
# memory usage: 2.2+ MB

# %% [markdown]
# #### 1.2) Check null values

# %%
data.isnull().sum()
# Out:
# Unnamed: 0         0
# id                 0
# name               0
# rating             0
# reviews            0
# host_name          8
# host_id            0
# address            0
# features           0
# amenities          0
# safety_rules       0
# hourse_rules       0
# img_links          0
# price              0
# country            0
# bathrooms          0
# beds               0
# guests             0
# toiles             0
# bedrooms           0
# studios            0
# checkin          800
# checkout        2450
# dtype: int64

# %% [markdown]
# #### 1.3) Check Duplicates

# %%
len(data) - data['id'].nunique()
# Out:
# 0

# %% [markdown]
# #### 1.4) Remove un-necessary columns

# %%
del data['Unnamed: 0']
del data['host_name']
del data['host_id']
del data['img_links']
del data['checkin']
del data['checkout']

# %% [markdown]
# ### 2. Data Cleaning

# %% [markdown]
# #### 2.1) Cleaning Country Column

# %%
data['country'] = data['country'].str.strip()

# %% [markdown]
# #### 2.2) Taking only the ones of India

# %%
data = data[data['country'] == 'India']

# %% [markdown]
# #### 2.3) Creating cities column

# %%
data['cities'] = data['address'].str.split(',').str[0]

# %% [markdown]
# #### 2.4) Taking only the ones of Manali adn has price less than 5000

# %%
data = data[data['cities'] == 'Manali']
data = data[data['price'] < 5000]

# %% [markdown]
# ### 3. Analyse the Data

# %% [markdown]
# #### 3.1) Finding top 10 based on Rating

# %%
data['rating'] = data['rating'].str.replace('New','0')
data['rating'] = data['rating'].astype('float')
data.sort_values(by='rating', ascending=False).head(10).to_csv('top_10_airbnb_rating.csv')

# %% [markdown]
# #### 3.2) Finding top 10 based on Reviews

# %%
data['reviews'] = data['reviews'].astype('int')

data.sort_values(by='reviews', ascending=False).head(10).to_csv('top_10_airbnb_reviews.csv')

# %% [markdown]
# #### 3.3) Finding top 10 based on Reviews as well as Rating

# %%
data['rating_and_review_filter'] = data['rating'] * data['reviews']

data.sort_values(by = 'rating_and_review_filter', ascending = False).head(10)
# Out:
#              id                                               name  rating  \
# 11993   6906342  The Abode - Shobla Pine Chalet - Room with bal...    4.72
# 5369   34613162                Quaint and Cozy rooms - Mokshastays    4.97
# 1794   30724547  Suite - Cozy and comfortable for Friends & Family    4.81
# 1784   24978026                                Apple Orchard House    4.78
# 5377   32545702            Beautiful & Peaceful Snow River, Manali    4.81
# 3173   13185211  The Abode - Shobla Pine Chalet - Room with bal...    4.75
# 5403   48928829      Mountain view Ride Inn Deluxe room  in Manali    4.90
# 5407   48819740  Beas River & Mt. View Superior Rm Ride Inn, Ma...    4.83
# 5359   50716559  Luxurious Room With A Hottub, Olive Manali Cot...    4.82
# 1806   31061284  Cider Chalet-E | 2BRK Apartment-SnowMountain View    4.65
#
#        reviews                                           address  \
# 11993      105                   Manali, Himachal Pradesh, India
# 5369        71                   Manali, Himachal Pradesh, India
# 1794        59                   Manali, Himachal Pradesh, India
# 1784        56                   Manali, Himachal Pradesh, India
# 5377        53                   Manali, Himachal Pradesh, India
# 3173        52                   Manali, Himachal Pradesh, India
# 5403        49                   Manali, Himachal Pradesh, India
# 5407        49                   Manali, Himachal Pradesh, India
# 5359        45  Manali, District- Kullu, Himachal Pradesh, India
# 1806        43                   Manali, Himachal Pradesh, India
#
#                                            features  \
# 11993   3 guests,1 bedroom,1 bed,1 private bathroom
# 5369         2 guests,1 bedroom,1 bed,1.5 bathrooms
# 1794   5 guests,1 bedroom,2 beds,1 private bathroom
# 1784            2 guests,1 bedroom,1 bed,1 bathroom
# 5377      12 guests,4 bedrooms,4 beds,4.5 bathrooms
# 3173    3 guests,1 bedroom,1 bed,1 private bathroom
# 5403    3 guests,1 bedroom,1 bed,1 private bathroom
# 5407    3 guests,1 bedroom,1 bed,1 private bathroom
# 5359    2 guests,1 bedroom,1 bed,1 private bathroom
# 1806         6 guests,2 bedrooms,2 beds,2 bathrooms
#
#                                                amenities  \
# 11993  Mountain view,Waterfront,Wifi,Free parking on ...
# 5369   Mountain view,Valley view,Wifi,Free parking on...
# 1794   Wifi,Dedicated workspace,Free parking on premi...
# 1784   Mountain view,Valley view,Kitchen,Pets allowed...
# 5377   Mountain view,River view,Waterfront,Wifi,Free ...
# 3173   Waterfront,Wifi,Free parking on premises,Pets ...
# 5403   Wifi,Free parking on premises,TV with standard...
# 5407   Wifi,Free driveway parking on premises,TV with...
# 5359   Mountain view,Valley view,Waterfront,Wifi,Dedi...
# 1806   Mountain view,Garden view,Waterfront,Kitchen,W...
#
#                                             safety_rules  \
# 11993  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 5369   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1794   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,S...
# 1784   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 5377   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3173   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 5403   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 5407   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 5359   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1806   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
#
#                                             hourse_rules  price country  \
# 11993  Check-in: After 12:00 pm,Check out: 11:00 am,S...   2853   India
# 5369   Check-in: 12:00 pm - 10:00 pm,Check out: 11:00...   3138   India
# 1794   Check-in: 12:00 pm - 2:00 pm,Check out: 11:00 ...   1610   India
# 1784   Check-in: Flexible,Check out: 1:00 am,No smoki...    913   India
# 5377   Check-in: After 12:00 pm,Check out: 11:00 am,S...   1162   India
# 3173   Check-in: After 12:00 pm,Check out: 11:00 am,P...   2853   India
# 5403   Check-in: After 1:00 pm,Check out: 11:00 am,No...   2199   India
# 5407   Check-in: After 1:00 pm,Check out: 11:00 am,No...   2742   India
# 5359   Check-in: 12:00 pm - 2:00 pm,Check out: 10:00 ...   2853   India
# 1806   Check-in: After 1:00 pm,Check out: 10:00 am,Se...   3278   India
#
#        bathrooms  beds  guests  toiles  bedrooms  studios  cities  \
# 11993          1     1       3       0         1        0  Manali
# 5369           1     1       2       0         1        0  Manali
# 1794           1     2       5       0         1        0  Manali
# 1784           1     1       2       0         1        0  Manali
# 5377           4     4      12       0         4        0  Manali
# 3173           1     1       3       0         1        0  Manali
# 5403           1     1       3       0         1        0  Manali
# 5407           1     1       3       0         1        0  Manali
# 5359           1     1       2       0         1        0  Manali
# 1806           2     2       6       0         2        0  Manali
#
#        rating_and_review_filter
# 11993                    495.60
# 5369                     352.87
# 1794                     283.79
# 1784                     267.68
# 5377                     254.93
# 3173                     247.00
# 5403                     240.10
# 5407                     236.67
# 5359                     216.90
# 1806                     199.95

# %% [markdown]
# ### 4. Top 10 Airbnbs in India based on Rating*Reviews

# %%
import pandas as pd
from tqdm.auto import tqdm


df = pd.read_csv('/content/datasets/Airbnb/airbnb_v2.csv')
df['country'] = df['country'].str.strip()
countries = df['country'].unique()


for country in tqdm(countries):

  df = pd.read_csv('/content/datasets/Airbnb/airbnb_v2.csv')

  df['country'] = df['country'].str.strip()
  df = df[df['country'] == country]

  df['rating'] = df['rating'].str.replace('New','0')
  df['rating'] = df['rating'].astype('float')

  df['reviews'] = df['reviews'].str.replace(',','').astype('int')

  df['rating_and_review_filter'] = df['rating'] * df['reviews']

  df.sort_values(by = 'rating_and_review_filter', ascending = False).head(10).to_csv('csvs/' + country + '.csv')
# Out:
#   0%|          | 0/119 [00:00<?, ?it/s]
# <ipython-input-131-11ff4c9f6bdd>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating'] = df['rating'].str.replace('New','0')
# <ipython-input-131-11ff4c9f6bdd>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating'] = df['rating'].astype('float')
# <ipython-input-131-11ff4c9f6bdd>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['reviews'] = df['reviews'].str.replace(',','').astype('int')
# <ipython-input-131-11ff4c9f6bdd>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating_and_review_filter'] = df['rating'] * df['reviews']
# <ipython-input-131-11ff4c9f6bdd>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating'] = df['rating'].str.replace('New','0')
# <ipython-input-131-11ff4c9f6bdd>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating'] = df['rating'].astype('float')
# <ipython-input-131-11ff4c9f6bdd>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['reviews'] = df['reviews'].str.replace(',','').astype('int')
# <ipython-input-131-11ff4c9f6bdd>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating_and_review_filter'] = df['rating'] * df['reviews']

# %% [markdown]
# ### 5. Saving the Zip

# %%
import zipfile
import os

def zip_folder(folder_path, output_path):

  with zipfile.ZipFile(output_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, _, files in os.walk(folder_path):
      for file in files:
        file_path = os.path.join(root, file)
        arcname = os.path.relpath(file_path, folder_path)
        zipf.write(file_path, arcname)


folder_path = 'csvs'  # Replace with the actual folder path
output_path = 'csvs.zip'  # Replace with the desired output path
zip_folder(folder_path, output_path)
