# %%
# !git clone https://github.com/AshishJangra27/datasets
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 328, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 328 (delta 19), reused 54 (delta 9), pack-reused 235 (from 1)
# Receiving objects: 100% (328/328), 278.62 MiB | 16.81 MiB/s, done.
# Resolving deltas: 100% (145/145), done.
# Updating files: 100% (225/225), done.

# %%
import pandas as pd

# %% [markdown]
# ### 1. Data Exploration

# %% [markdown]
# #### 1.1) Loading the Dataset

# %%
df = pd.read_csv('/content/datasets/Job Postings/jobs.csv.zip')
df.head(2)
# Out:
#          job_id                                       job_role    company  \
# 0  7.012301e+10  Branch Banking - Calling For Women Candidates  Hdfc Bank
# 1  6.012391e+10                   Product Owner Senior Manager  Accenture
#
#   experience         salary  \
# 0    1-6 Yrs  Not disclosed
# 1  11-15 Yrs  Not disclosed
#
#                                             location  rating        reviews  \
# 0  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...     4.0  39110 Reviews
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
#
#                                      resposibilities  posted_on  \
# 0     Customer Service,Sales,Relationship Management  1 Day Ago
# 1  Product management,Market analysis,Change mana...  1 Day Ago
#
#                                             job_link  \
# 0  https://www.naukri.com/job-listings-branch-ban...
# 1  https://www.naukri.com/job-listings-product-ow...
#
#                                         company_link
# 0  https://www.naukri.com/hdfc-bank-jobs-careers-213
# 1  https://www.naukri.com/accenture-jobs-careers-...

# %% [markdown]
# #### 1.2) Removing "posted_on" Columns

# %%
del df['posted_on']

# %% [markdown]
# #### 1.3) Check Null Values

# %%
df.isnull().sum()
# Out:
# job_id               480
# job_role             480
# company              481
# experience          1749
# salary               480
# location            1706
# rating             36199
# reviews            36199
# resposibilities      500
# job_link             480
# company_link         480
# dtype: int64

# %% [markdown]
# #### 1.4) Removign rows with null values in job_id,company and responsibility column

# %%
df.dropna(subset = ['job_id','company','resposibilities'], inplace = True)

# %% [markdown]
# #### 1.5) Filling Null values in location and experience column with most frequent

# %%
df['location'].fillna(df['location'].mode()[0], inplace = True)
df['experience'].fillna(df['experience'].mode()[0], inplace = True)
# Out:
# <ipython-input-7-2a1fddb959e7>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['location'].fillna(df['location'].mode()[0], inplace = True)
# <ipython-input-7-2a1fddb959e7>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['experience'].fillna(df['experience'].mode()[0], inplace = True)

# %% [markdown]
# #### 1.6) Filling Null values in rating and reviews column with 0

# %%
df['rating'].fillna(0.0,inplace = True)
df['reviews'].fillna('0 Reviews',inplace = True)
# Out:
# <ipython-input-8-96e8ba36cda5>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rating'].fillna(0.0,inplace = True)
# <ipython-input-8-96e8ba36cda5>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['reviews'].fillna('0 Reviews',inplace = True)

# %%
df.isnull().sum()
# Out:
# job_id             0
# job_role           0
# company            0
# experience         0
# salary             0
# location           0
# rating             0
# reviews            0
# resposibilities    0
# job_link           0
# company_link       0
# dtype: int64

# %% [markdown]
# #### 1.7) Remove Duplicates

# %%
df.drop_duplicates(subset=['job_link'],inplace = True)

# %% [markdown]
# ### 2. Data Cleaning

# %% [markdown]
# #### 2.1) Cleaning Job_id Column

# %%
df['job_id'] = df['job_id'].astype('int').astype('str')

# %% [markdown]
# #### 2.2) Creating Company ID Column

# %%
df['company_id'] = df['company_link'].str.split('-').str[-1]

# %% [markdown]
# #### 2.3) Removing Companies with company_id = 0

# %%
df = df[df['company_id'] != '0']

# %% [markdown]
# #### 2.4) Cleaning Compan

# %%
df['experience'].value_counts()
# Out:
# experience
# 5-10 Yrs     8720
# 3-8 Yrs      3900
# 2-7 Yrs      3047
# 1-6 Yrs      3012
# 4-9 Yrs      2913
#              ...
# 21-28 Yrs       1
# 18-26 Yrs       1
# 2-21 Yrs        1
# 25-28 Yrs       1
# 20-29 Yrs       1
# Name: count, Length: 231, dtype: int64

# %%
df[df['experience'] == '5-10 Yrs']
# Out:
#              job_id                                           job_role  \
# 5       60123006373  ServiceNow Consultants / Sr. Consultants ( Dev...
# 6       50123005519  C++ Developer (Looking For immediate joiners o...
# 14      50123004500                           Automation Test Engineer
# 22     151222006599                                  PowerBI Developer
# 29      81122009258  EY India is Hiring For SAP SD Functional Consu...
# ...             ...                                                ...
# 73633  161122008857            Factory Medical Officer at Dahej,Gujrat
# 73707   70123004364                                        Staff Nurse
# 73711   60123009573  Job opening - Retail Branch Banking- CASA Sale...
# 73736   50123008739     Hiring For Domestic Customer Support Executive
# 73752  291222003354  Walk-In interview - Electrical Technician & DG...
#
#                                  company experience  \
# 5                               Deloitte   5-10 Yrs
# 6                              Capgemini   5-10 Yrs
# 14                               HCLTech   5-10 Yrs
# 22                                    EY   5-10 Yrs
# 29                                    EY   5-10 Yrs
# ...                                  ...        ...
# 73633                   G. K. Associates   5-10 Yrs
# 73707            Sheeba Medical Services   5-10 Yrs
# 73711        Suryoday Small Finance Bank   5-10 Yrs
# 73736  Blinks India Solutions & Services   5-10 Yrs
# 73752                          Ig3 Infra   5-10 Yrs
#
#                           salary  \
# 5                  Not disclosed
# 6                  Not disclosed
# 14                 Not disclosed
# 22                 Not disclosed
# 29     13,00,000 - 22,50,000 PA.
# ...                          ...
# 73633  10,00,000 - 15,00,000 PA.
# 73707    1,25,000 - 3,50,000 PA.
# 73711              Not disclosed
# 73736    1,25,000 - 2,25,000 PA.
# 73752      50,000 - 2,50,000 PA.
#
#                                                 location  rating  \
# 5      Kolkata, Hyderabad/Secunderabad, Pune, Chennai...     4.0
# 6      Hybrid - Kolkata, Hyderabad/Secunderabad, Pune...     3.9
# 14                                   Bangalore/Bengaluru     3.8
# 22                     Hybrid - Pune, Mumbai (All Areas)     3.8
# 29     Hybrid - Kolkata, Hyderabad/Secunderabad, Pune...     3.8
# ...                                                  ...     ...
# 73633                                              Dahej     0.0
# 73707                                Bangalore/Bengaluru     0.0
# 73711                                Bangalore/Bengaluru     4.0
# 73736                                Bangalore/Bengaluru     0.0
# 73752                                Bangalore/Bengaluru     4.0
#
#              reviews                                    resposibilities  \
# 5      10263 Reviews                        Itam,ITSM,Hrsd,GRC,Itom,CSD
# 6      23786 Reviews                  C++,stl,Node js,SVN,Go,Git,Python
# 14     18348 Reviews          webdriverio,javascript,Automation Testing
# 22      6258 Reviews                            pagination,Power Bi,Dax
# 29      6258 Reviews                 SAP SD,Sap Hana,SAP Implementation
# ...              ...                                                ...
# 73633      0 Reviews  monitor hospitalized patients,Participate in s...
# 73707      0 Reviews           BSC NURSING,DIPLOMA NURSING,ANM,Dmlt,GNM
# 73711    621 Reviews  Sales,Banking,Retail Branch Banking,Promotions...
# 73736      0 Reviews  BPO,Call Center,AEGIS STARTEK,Solving Queries,...
# 73752     27 Reviews  Electrical Maintenance,DG,electrical technicia...
#
#                                                 job_link  \
# 5      https://www.naukri.com/job-listings-servicenow...
# 6      https://www.naukri.com/job-listings-c-develope...
# 14     https://www.naukri.com/job-listings-automation...
# 22     https://www.naukri.com/job-listings-powerbi-de...
# 29     https://www.naukri.com/job-listings-ey-india-i...
# ...                                                  ...
# 73633  https://www.naukri.com/job-listings-factory-me...
# 73707  https://www.naukri.com/job-listings-staff-nurs...
# 73711  https://www.naukri.com/job-listings-opening-re...
# 73736  https://www.naukri.com/job-listings-hiring-for...
# 73752  https://www.naukri.com/job-listings-walk-in-in...
#
#                                             company_link company_id
# 5      https://www.naukri.com/deloitte-jobs-careers-1706       1706
# 6      https://www.naukri.com/capgemini-jobs-careers-649        649
# 14       https://www.naukri.com/hcltech-jobs-careers-460        460
# 22           https://www.naukri.com/ey-jobs-careers-9156       9156
# 29           https://www.naukri.com/ey-jobs-careers-9156       9156
# ...                                                  ...        ...
# 73633  https://www.naukri.com/g-k-associates-jobs-car...      78426
# 73707  https://www.naukri.com/sheeba-medical-services...  123634285
# 73711  https://www.naukri.com/suryoday-small-finance-...    3357842
# 73736  https://www.naukri.com/blinks-india-solutions-...  123583039
# 73752  https://www.naukri.com/heritage-madurai-jobs-c...     606785
#
# [8720 rows x 12 columns]

# %%
df['company_link'].value_counts()
# Out:
# company_link
# https://www.naukri.com/lavya-associates-hr-services-jobs-careers-932996         5222
# https://www.naukri.com/accenture-jobs-careers-7682                              2928
# https://www.naukri.com/varite-jobs-careers-82233                                 892
# https://www.naukri.com/hucon-jobs-careers-1001716                                852
# https://www.naukri.com/ibm-jobs-careers-16987                                    656
#                                                                                 ...
# https://www.naukri.com/gnx-group-jobs-careers-6368018                              1
# https://www.naukri.com/congruex-jobs-careers-3715576                               1
# https://www.naukri.com/ajnalens-a-unit-of-dimension-nxg-jobs-careers-7077783       1
# https://www.naukri.com/solaura-power-jobs-careers-123628451                        1
# https://www.naukri.com/entrivis-tech-jobs-careers-123617159                        1
# Name: count, Length: 13845, dtype: int64

# %%
df
# Out:
#              job_id                                           job_role  \
# 0       70123006070      Branch Banking - Calling For Women Candidates
# 1       60123905908                       Product Owner Senior Manager
# 2       60123905898  Employee Relations and Policies Associate Manager
# 3       60123905897         Employee Relations and Policies Specialist
# 4       60123008332                                  SAP BO Consultant
# ...             ...                                                ...
# 73762   20123002989            Partner Success Executive/Edtech/Punjab
# 73763   20123002957            Partner Success Associate/Edtech/Punjab
# 73764  231222003986  Hiring For International Voice Process | Gurga...
# 73765  171220001449                                   Fresher Engineer
# 73766   71022008732            Anatomy Trainer - Part Time / Full time
#
#                      company experience                   salary  \
# 0                  Hdfc Bank    1-6 Yrs            Not disclosed
# 1                  Accenture  11-15 Yrs            Not disclosed
# 2                  Accenture    3-7 Yrs            Not disclosed
# 3                  Accenture    3-7 Yrs            Not disclosed
# 4                   Mindtree    5-7 Yrs            Not disclosed
# ...                      ...        ...                      ...
# 73762       Parth Associates    1-5 Yrs  7,00,000 - 8,50,000 PA.
# 73763       Parth Associates    1-5 Yrs  7,00,000 - 8,50,000 PA.
# 73764   First Step Solutions    1-4 Yrs  3,00,000 - 4,50,000 PA.
# 73765                 Sofcon    0-2 Yrs            Not disclosed
# 73766  Indian Healthcare BPO    1-6 Yrs            Not disclosed
#
#                                                 location  rating  \
# 0      Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...     4.0
# 1      Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1
# 2      Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1
# 3      Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1
# 4      Hybrid - Kolkata, Hyderabad/Secunderabad, Pune...     4.1
# ...                                                  ...     ...
# 73762                    Jalandhar, Chandigarh, Amritsar     0.0
# 73763                            Ludhiana, Patiala, Moga     0.0
# 73764                        New Delhi, Gurgaon/Gurugram     0.0
# 73765  Kota, Udaipur, Banswara, Bhiwadi, Jaipur, Alwa...     2.8
# 73766    Hybrid - Pondicherry/Puducherry, Salem, Chennai     0.0
#
#              reviews                                    resposibilities  \
# 0      39110 Reviews     Customer Service,Sales,Relationship Management
# 1      32129 Reviews  Product management,Market analysis,Change mana...
# 2      32129 Reviews  Business process,Change management,Team manage...
# 3      32129 Reviews  Business process,Change management,Team manage...
# 4       3759 Reviews  SAP BO,PL / SQL,Oracle SQL,SAP Business Object...
# ...              ...                                                ...
# 73762      0 Reviews  CRM,Communication Skills,Presentation Skills,C...
# 73763      0 Reviews  CRM,Communication Skills,Presentation Skills,C...
# 73764      0 Reviews  Customer Service,US Process,Hospitality,Custom...
# 73765      3 Reviews  ENGINEERING,B Tech Fresher,AutoCAD,Degree,PLC,...
# 73766      0 Reviews  Lecturer Activities,Nursing Education,Trainer,...
#
#                                                 job_link  \
# 0      https://www.naukri.com/job-listings-branch-ban...
# 1      https://www.naukri.com/job-listings-product-ow...
# 2      https://www.naukri.com/job-listings-employee-r...
# 3      https://www.naukri.com/job-listings-employee-r...
# 4      https://www.naukri.com/job-listings-sap-bo-con...
# ...                                                  ...
# 73762  https://www.naukri.com/job-listings-partner-su...
# 73763  https://www.naukri.com/job-listings-partner-su...
# 73764  https://www.naukri.com/job-listings-hiring-for...
# 73765  https://www.naukri.com/job-listings-fresher-en...
# 73766  https://www.naukri.com/job-listings-anatomy-tr...
#
#                                             company_link
# 0      https://www.naukri.com/hdfc-bank-jobs-careers-213
# 1      https://www.naukri.com/accenture-jobs-careers-...
# 2      https://www.naukri.com/accenture-jobs-careers-...
# 3      https://www.naukri.com/accenture-jobs-careers-...
# 4      https://www.naukri.com/mindtree-jobs-careers-3...
# ...                                                  ...
# 73762  https://www.naukri.com/parth-associates-jobs-c...
# 73763  https://www.naukri.com/parth-associates-jobs-c...
# 73764  https://www.naukri.com/first-step-solutions-jo...
# 73765  https://www.naukri.com/sofcon-jobs-careers-110403
# 73766  https://www.naukri.com/indian-healthcare-bpo-j...
#
# [72988 rows x 11 columns]

# %%
- Number of Active Jobs in Any Company | Top Companies
- Company which provides maximum/minimum average Salary
- Salary vs Experience of any Company
- Company hiring for most numbers of locations

# %%
1. Analyze Company Ratings
  - Calculate the average rating for each company
  - Identify companies with the highest and lowest average ratings.
  - Compare the distribution of ratings across different companies.
  - Calculate the total number of reviews for each company. | Sort to get most and LiteralString

- List the top 10 companies based on average rating and number of reviews.
- Analyze the characteristics and practices of these top-rated companies. | Most Popular Responsibilities of top 100 companies
