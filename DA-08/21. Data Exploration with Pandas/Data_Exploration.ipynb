# %% [markdown]
# ### 1. Loading Libraries & Downloading Datsets

# %%
import numpy as np
import pandas as pd

# !git clone https://github.com/AshishJangra27/datasets

# %% [markdown]
# ### Loading dataset

# %%
pd.read_csv('/content/datasets/Airbnb/airbnb.csv')
# Out:
#              id                                               name rating  \
# 0      49849504                                     Perla bungalov   4.71
# 1      50891766  Authentic Beach Architect Sheltered Villa with...    New
# 2      50699164                                  cottages sataplia   4.85
# 3      49871422                        Sapanca Breathable Bungalow    5.0
# 4      51245886                                      Bungalov Ev 2    New
# ...         ...                                                ...    ...
# 14451  44697740            Brown Dome House No. 3, full of healing   4.94
# 14452  29975283       Bubble Hotel Ubud with Bathtub under the Sky   4.67
# 14453  32977697                                   Paradise Eco Hub   4.67
# 14454   8006146     WisDOME - Mentigi Bay Village - Gilis - Lombok   4.86
# 14455  40547903   Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]   4.85
#
#       reviews                              host_name      host_id  \
# 0          64    Entire bungalow hosted by Mehmetcan  357334205.0
# 1         NaN           Entire villa hosted by Fatih  386223873.0
# 2          68          Entire cabin hosted by Giorgi  409690853.0
# 3          13        Entire bungalow hosted by Melih  401873242.0
# 4         NaN  Entire bungalow hosted by Arp Sapanca  414884116.0
# ...       ...                                    ...          ...
# 14451      16                   Dome hosted by Aidan  161552316.0
# 14452       6                  Tent hosted by Martha  118954227.0
# 14453       3   Private room in dome hosted by Silas  175214568.0
# 14454       7                 Dome hosted by Cempaka     718423.0
# 14455      13                    Dome hosted by Achy  246470880.0
#
#                                                  address  \
# 0                               Kartepe, Kocaeli, Turkey
# 1                                   Kaş, Antalya, Turkey
# 2                                       Imereti, Georgia
# 3                               Sapanca, Sakarya, Turkey
# 4                               Sapanca, Sakarya, Turkey
# ...                                                  ...
# 14451  Imhoe-myeon, Jindo, South Jeolla Province, Sou...
# 14452                                 Gianyar, Indonesia
# 14453                                     Kabale, Uganda
# 14454        Gunung Sari, Nusa Tenggara Barat, Indonesia
# 14455                              Uruma, Okinawa, Japan
#
#                                            features  \
# 0              2 guests,2 bedrooms,1 bed,1 bathroom
# 1            4 guests,2 bedrooms,2 beds,2 bathrooms
# 2              4 guests,1 bedroom,3 beds,1 bathroom
# 3              4 guests,1 bedroom,2 beds,1 bathroom
# 4               2 guests,1 bedroom,1 bed,1 bathroom
# ...                                             ...
# 14451                          4 guests,8 bathrooms
# 14452     2 guests,1 bedroom,1 bed,Toilet with sink
# 14453  2 guests,1 bedroom,2 beds,1 private bathroom
# 14454      8 guests,2 bedrooms,4 beds,2.5 bathrooms
# 14455          5 guests,1 bedroom,2 beds,1 bathroom
#
#                                                amenities  \
# 0      Mountain view,Valley view,Lake access,Kitchen,...
# 1      Kitchen,Wifi,Dedicated workspace,Free parking ...
# 2      Mountain view,Kitchen,Wifi,Dedicated workspace...
# 3      Mountain view,Valley view,Kitchen,Wifi,Free pa...
# 4      Kitchen,Wifi,Free parking on premises,TV,Air c...
# ...                                                  ...
# 14451  Kitchen,Wifi,Free parking on premises,Private ...
# 14452  Wifi,Free on-street parking,Air conditioning,G...
# 14453  Wifi,Breakfast,Long-term stays allowed,Unavail...
# 14454  Kitchen,Wifi,Dedicated workspace,Free parking ...
# 14455  Sea view,Beach access – Beachfront,Kitchen,Wif...
#
#                                             safety_rules  \
# 0      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 1      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 2      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 3      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 4      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# ...                                                  ...
# 14451  󹀁,Airbnb's COVID-19 safety practices apply,󱠁,C...
# 14452  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14453  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...
# 14454  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...
# 14455  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,S...
#
#                                             hourse_rules  \
# 0      Check-in: Flexible,Check out: 12:00 pm,Pets ar...
# 1      Check-in: 4:00 pm - 11:00 pm,Check out: 10:00 ...
# 2      Check-in: After 1:00 pm,Check out: 12:00 pm,Se...
# 3      Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# 4      Check-in: After 2:00 pm,Check out: 12:00 pm,No...
# ...                                                  ...
# 14451  Check-in: 3:00 pm - 11:00 pm,Check out: 11:00 ...
# 14452  Check-in: 3:00 pm - 10:00 pm,Check out: 12:00 ...
# 14453                            Check-in: After 3:00 pm
# 14454  Check-in: Flexible,Check out: 12:00 pm,No pets...
# 14455  Check-in: After 4:00 pm,Check out: 11:00 am,Se...
#
#                                                img_links              price
# 0      https://a0.muscache.com/im/pictures/a5da5cb7-c...   ₹8,078 per night
# 1      https://a0.muscache.com/im/pictures/61b70855-2...   ₹4,665 per night
# 2      https://a0.muscache.com/im/pictures/miso/Hosti...   ₹5,991 per night
# 3      https://a0.muscache.com/im/pictures/72e6396e-e...  ₹11,339 per night
# 4      https://a0.muscache.com/im/pictures/73973308-e...   ₹6,673 per night
# ...                                                  ...                ...
# 14451  https://a0.muscache.com/im/pictures/miso/Hosti...   ₹4,288 per night
# 14452  https://a0.muscache.com/im/pictures/5ba944b2-b...  ₹15,200 per night
# 14453  https://a0.muscache.com/im/pictures/1f442c84-4...   ₹9,103 per night
# 14454  https://a0.muscache.com/im/pictures/105116799/...  ₹42,262 per night
# 14455  https://a0.muscache.com/im/pictures/9b04ee4c-c...   ₹9,909 per night
#
# [14456 rows x 13 columns]

# %%
df = pd.read_csv('/content/datasets/Airbnb/airbnb_v2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        id                                               name  \
# 0           0  49849504                                     Perla bungalov
# 1           1  50891766  Authentic Beach Architect Sheltered Villa with...
# 2           2  50699164                                  cottages sataplia
# 3           3  49871422                        Sapanca Breathable Bungalow
# 4           4  51245886                                      Bungalov Ev 2
#
#   rating reviews    host_name      host_id                   address  \
# 0   4.71      64    Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1    New       0        Fatih  386223873.0      Kaş, Antalya, Turkey
# 2   4.85      68       Giorgi  409690853.0          Imereti, Georgia
# 3    5.0      13        Melih  401873242.0  Sapanca, Sakarya, Turkey
# 4    New       0  Arp Sapanca  414884116.0  Sapanca, Sakarya, Turkey
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# 1  4 guests,2 bedrooms,2 beds,2 bathrooms
# 2    4 guests,1 bedroom,3 beds,1 bathroom
# 3    4 guests,1 bedroom,2 beds,1 bathroom
# 4     2 guests,1 bedroom,1 bed,1 bathroom
#
#                                            amenities  ...  price   country  \
# 0  Mountain view,Valley view,Lake access,Kitchen,...  ...   8078    Turkey
# 1  Kitchen,Wifi,Dedicated workspace,Free parking ...  ...   4665    Turkey
# 2  Mountain view,Kitchen,Wifi,Dedicated workspace...  ...   5991   Georgia
# 3  Mountain view,Valley view,Kitchen,Wifi,Free pa...  ...  11339    Turkey
# 4  Kitchen,Wifi,Free parking on premises,TV,Air c...  ...   6673    Turkey
#
#   bathrooms  beds guests  toiles  bedrooms  studios              checkin  \
# 0         1     1      2       0         2        0             Flexible
# 1         2     2      4       0         2        0   4 00 pm - 11 00 pm
# 2         1     3      4       0         1        0        After 1 00 pm
# 3         1     2      4       0         1        0        After 2 00 pm
# 4         1     1      2       0         1        0        After 2 00 pm
#
#     checkout
# 0   12 00 pm
# 1   10 00 am
# 2   12 00 pm
# 3   12 00 pm
# 4   12 00 pm
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#        Unnamed: 0        id                                              name  \
# 12800       12800  44697740           Brown Dome House No. 3, full of healing
# 12801       12801  29975283      Bubble Hotel Ubud with Bathtub under the Sky
# 12802       12802  32977697                                  Paradise Eco Hub
# 12803       12803   8006146    WisDOME - Mentigi Bay Village - Gilis - Lombok
# 12804       12804  40547903  Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]
#
#       rating reviews host_name      host_id  \
# 12800   4.94      16     Aidan  161552316.0
# 12801   4.67       6    Martha  118954227.0
# 12802   4.67       3     Silas  175214568.0
# 12803   4.86       7   Cempaka     718423.0
# 12804   4.85      13      Achy  246470880.0
#
#                                                  address  \
# 12800  Imhoe-myeon, Jindo, South Jeolla Province, Sou...
# 12801                                 Gianyar, Indonesia
# 12802                                     Kabale, Uganda
# 12803        Gunung Sari, Nusa Tenggara Barat, Indonesia
# 12804                              Uruma, Okinawa, Japan
#
#                                            features  \
# 12800                          4 guests,8 bathrooms
# 12801     2 guests,1 bedroom,1 bed,Toilet with sink
# 12802  2 guests,1 bedroom,2 beds,1 private bathroom
# 12803      8 guests,2 bedrooms,4 beds,2.5 bathrooms
# 12804          5 guests,1 bedroom,2 beds,1 bathroom
#
#                                                amenities  ...  price  \
# 12800  Kitchen,Wifi,Free parking on premises,Private ...  ...   4288
# 12801  Wifi,Free on-street parking,Air conditioning,G...  ...  15200
# 12802  Wifi,Breakfast,Long-term stays allowed,Unavail...  ...   9103
# 12803  Kitchen,Wifi,Dedicated workspace,Free parking ...  ...  42262
# 12804  Sea view,Beach access – Beachfront,Kitchen,Wif...  ...   9909
#
#             country bathrooms  beds guests  toiles  bedrooms  studios  \
# 12800   South Korea         8     0      4       0         0        0
# 12801     Indonesia         0     1      2       1         1        0
# 12802        Uganda         1     2      2       0         1        0
# 12803     Indonesia         2     4      8       0         2        0
# 12804         Japan         1     2      5       0         1        0
#
#                    checkin   checkout
# 12800   3 00 pm - 11 00 pm   11 00 am
# 12801   3 00 pm - 10 00 pm   12 00 pm
# 12802        After 3 00 pm        NaN
# 12803             Flexible   12 00 pm
# 12804        After 4 00 pm   11 00 am
#
# [5 rows x 23 columns]

# %%
df.head(2)
# Out:
#    Unnamed: 0        id                                               name  \
# 0           0  49849504                                     Perla bungalov
# 1           1  50891766  Authentic Beach Architect Sheltered Villa with...
#
#   rating reviews  host_name      host_id                   address  \
# 0   4.71      64  Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1    New       0      Fatih  386223873.0      Kaş, Antalya, Turkey
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# 1  4 guests,2 bedrooms,2 beds,2 bathrooms
#
#                                            amenities  ... price  country  \
# 0  Mountain view,Valley view,Lake access,Kitchen,...  ...  8078   Turkey
# 1  Kitchen,Wifi,Dedicated workspace,Free parking ...  ...  4665   Turkey
#
#   bathrooms  beds guests  toiles  bedrooms  studios              checkin  \
# 0         1     1      2       0         2        0             Flexible
# 1         2     2      4       0         2        0   4 00 pm - 11 00 pm
#
#     checkout
# 0   12 00 pm
# 1   10 00 am
#
# [2 rows x 23 columns]

# %%
df.describe()
# Out:
#          Unnamed: 0            id       host_id         price     bathrooms  \
# count  12805.000000  1.280500e+04  1.280500e+04  1.280500e+04  12805.000000
# mean    6402.000000  7.525187e+16  1.638192e+08  1.769780e+04      1.874424
# std     3696.629433  2.007933e+17  1.413622e+08  4.569364e+04      2.091399
# min        0.000000  1.313100e+04  2.303900e+04  3.930000e+02      0.000000
# 25%     3201.000000  2.023958e+07  3.700032e+07  3.994000e+03      1.000000
# 50%     6402.000000  3.682229e+07  1.256459e+08  8.175000e+03      1.000000
# 75%     9603.000000  4.999760e+07  2.639623e+08  1.606200e+04      2.000000
# max    12804.000000  7.017905e+17  4.758973e+08  1.907963e+06     50.000000
#
#                beds        guests        toiles      bedrooms       studios
# count  12805.000000  12805.000000  12805.000000  12805.000000  12805.000000
# mean       3.316751      5.213745      0.019211      2.136041      0.023585
# std        4.037791      3.808830      0.137272      2.359005      0.151757
# min        0.000000      1.000000      0.000000      0.000000      0.000000
# 25%        1.000000      2.000000      0.000000      1.000000      0.000000
# 50%        2.000000      4.000000      0.000000      1.000000      0.000000
# 75%        4.000000      6.000000      0.000000      3.000000      0.000000
# max       98.000000     16.000000      1.000000     50.000000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12805 entries, 0 to 12804
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    12805 non-null  int64
#  1   id            12805 non-null  int64
#  2   name          12805 non-null  object
#  3   rating        12805 non-null  object
#  4   reviews       12805 non-null  object
#  5   host_name     12797 non-null  object
#  6   host_id       12805 non-null  float64
#  7   address       12805 non-null  object
#  8   features      12805 non-null  object
#  9   amenities     12805 non-null  object
#  10  safety_rules  12805 non-null  object
#  11  hourse_rules  12805 non-null  object
#  12  img_links     12805 non-null  object
#  13  price         12805 non-null  int64
#  14  country       12805 non-null  object
#  15  bathrooms     12805 non-null  int64
#  16  beds          12805 non-null  int64
#  17  guests        12805 non-null  int64
#  18  toiles        12805 non-null  int64
#  19  bedrooms      12805 non-null  int64
#  20  studios       12805 non-null  int64
#  21  checkin       12005 non-null  object
#  22  checkout      10355 non-null  object
# dtypes: float64(1), int64(9), object(13)
# memory usage: 2.2+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# id                 0
# name               0
# rating             0
# reviews            0
# host_name          8
# host_id            0
# address            0
# features           0
# amenities          0
# safety_rules       0
# hourse_rules       0
# img_links          0
# price              0
# country            0
# bathrooms          0
# beds               0
# guests             0
# toiles             0
# bedrooms           0
# studios            0
# checkin          800
# checkout        2450
# dtype: int64

# %%
df = df.dropna(subset = 'host_name')

# %%
df = df.dropna()

# %%
len(df)
# Out:
# 10189

# %%
df['host_name'] = df['host_name'].fillna('Unknown')

# %%
len(df)
# Out:
# 12805

# %%
len(df['id'])
# Out:
# 12805

# %%
df['id'].nunique()
# Out:
# 12805

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'rating', 'reviews', 'host_name', 'host_id',
#        'address', 'features', 'amenities', 'safety_rules', 'hourse_rules',
#        'img_links', 'price', 'country', 'bathrooms', 'beds', 'guests',
#        'toiles', 'bedrooms', 'studios', 'checkin', 'checkout'],
#       dtype='object')

# %%
del df['Unnamed: 0']

# %%
df['rating'].replace('New', 0, inplace = True)
df['rating'] = df['rating'].astype('float')

# %%
df['rating'].mean()
# Out:
# np.float64(3.249823506442796)

# %%
df['reviews'] = df['reviews'].str.replace(',','').astype('int')

# %%
df['reviews'].mean()
# Out:
# np.float64(36.1400234283483)

# %%
df['clean_country'] = df['address'].str.split(',').str[-1].str.strip()

# %%
df[df['address'].str.split(',').str.len() == 5]
# Out:
#                        id                                               name  \
# 726              31948358                           Unique One Bed Apartment
# 833              45372012                                       Blue heights
# 835              30009524             Ashvem blue nest(Britto’s guest house)
# 1044             16199324                Comfortable cabanas in the paradise
# 1138              7055469     Cute Bamboo Bungalow Erawan N.Park Shanti Farm
# 3363             53259108  2 bedrooms appartement with enclosed garden an...
# 3402              6235753                          Trullo Colori del Salento
# 3465             43252774    Ai Trulli | Between Ostuni & Cisternino, Puglia
# 3564             35992843                                    Trulli Pasquina
# 4660             33463825  Terrace like a cafe where you can enjoy a barb...
# 5270             16582459                One double bed room for two people.
# 5357             32585568  GlampEco Stays Manali, Rustic home with epic view
# 5360   588094596325925638    Pet-friendly holiday cottage + wifi near Naggar
# 5902             15426406              Caldera View, Cave House, Plunge Pool
# 6636             15909457                                 Ac Room near Beach
# 7037             14997423      [Traditional Japanese Style Suite] ZEN Hostel
# 8250             49044341  # Gapyeong # Nature # Dog Pension # Individual...
# 10407            53719575             Beautiful Four Bedroom Villa with Pool
# 10851            46755748  139 Studios (Product and Self Photography, Spa...
# 11729            40667955             Nubian Kingdom Aragheed House (Room 2)
# 12777            50358163                             mushroom house pension
#
#        rating  reviews             host_name      host_id  \
# 726      4.92       25                Kushag    6664835.0
# 833      4.87       31              Clifford  225564379.0
# 835      4.70       42              Clifford  225564379.0
# 1044     4.60      127               Krishan  105794101.0
# 1138     4.62       13                   Kim   34795931.0
# 3363     0.00        0  Loic, Estelle And Co  431170929.0
# 3402     4.93       56              Caterina   21910788.0
# 3465     5.00        5              Giovanni  343940523.0
# 3564     4.59      101              Giuseppe  220091488.0
# 4660     4.94      297                    은아  242197018.0
# 5270     0.00        0             Smile Box  109298461.0
# 5357     4.85       54                Akshat  244898571.0
# 5360     5.00        4                Jaypal  127966387.0
# 5902     4.82       17                 Babis   40355666.0
# 6636     4.80       11                   Joe   36399693.0
# 7037     4.77       39            ZEN Hostel   92548480.0
# 8250     0.00        1                  Onda  331846516.0
# 10407    5.00        3               Antonio   74845402.0
# 10851    0.00        0                    선미  377859568.0
# 11729    5.00        3                Bassam  244176816.0
# 12777    4.76       22                    호종  406689641.0
#
#                                                  address  \
# 726    Walkeshwar, Malabar Hill, Mumbai, Maharashtra,...
# 833                  Ashvem, Mandrem, Pernem, Goa, India
# 835                  Ashvem, Mandrem, Pernem, Goa, India
# 1044   Tangalle, Southern Province, LK, southern, Sri...
# 1138   Kanchanaburi Erawan National Park, Kanchanabur...
# 3363         Punta Penna, Brindisi, Puglia, Italy, Italy
# 3402              Ostuni, Brindisi, Puglia, Italy, Italy
# 3465              Ostuni, Brindisi, Puglia, Italy, Italy
# 3564       Martina Franca, Taranto, Puglia, Italy, Italy
# 4660   Deokjindong 1(il)-ga, Deokjin-gu, Jeonju, Nort...
# 5270                ตำบล หนองหิน, เลย, TH, เลย, Thailand
# 5357   Hamta Village, Prini, Manali, Himachal Pradesh...
# 5360   Kullu - Naggar - Manali Rd,, Manali, Himachal ...
# 5902      Imerovigli, Santorini, Thira, Cyclades, Greece
# 6636                     Arambol, Goa, India, Goa, India
# 7037   3031 Hirao,Yamanouchi-machi, Shimotakai-gun, N...
# 8250   Sang-myeon, 상면, Gapyeong-gun, Gyeonggi Provinc...
# 10407    Donwaddo, Salvador Do Mundo, Bardez, Goa, India
# 10851  Jung-dong, Giheung-gu, Yongin-si, Gyeonggi Pro...
# 11729  Assouan, Aswan, Assouan, Aswan Governorate, Egypt
# 12777  Homigot-myeon, Nam-gu, Pohang, North Gyeongsan...
#
#                                                 features  \
# 726                 4 guests,1 bedroom,1 bed,2 bathrooms
# 833                4 guests,2 bedrooms,2 beds,1 bathroom
# 835                4 guests,2 bedrooms,2 beds,1 bathroom
# 1044          2 guests,1 bedroom,1 bed,1 shared bathroom
# 1138                 2 guests,1 bedroom,1 bed,1 bathroom
# 3363               4 guests,2 bedrooms,3 beds,1 bathroom
# 3402              6 guests,3 bedrooms,4 beds,2 bathrooms
# 3465              8 guests,4 bedrooms,4 beds,4 bathrooms
# 3564               4 guests,2 bedrooms,3 beds,1 bathroom
# 4660             5 guests,1 bedroom,2 beds,1.5 bathrooms
# 5270                 2 guests,1 bedroom,1 bed,1 bathroom
# 5357         2 guests,1 bedroom,1 bed,4 shared bathrooms
# 5360             10 guests,3 bedrooms,7 beds,3 bathrooms
# 5902              5 guests,2 bedrooms,2 beds,2 bathrooms
# 6636         2 guests,1 bedroom,1 bed,1 private bathroom
# 7037   6 guests,1 bedroom,6 beds,Shared toilet with sink
# 8250              6 guests,2 bedrooms,2 beds,2 bathrooms
# 10407           8 guests,4 bedrooms,4 beds,5.5 bathrooms
# 10851                               8 guests,0 bathrooms
# 11729        3 guests,1 bedroom,3 beds,1 shared bathroom
# 12777               10 guests,1 bedroom,1 bed,1 bathroom
#
#                                                amenities  \
# 726    Kitchen,Wifi,TV,Free washer – In unit,Dryer,AC...
# 833    Mountain view,Beach access – Beachfront,Kitche...
# 835    Beach access – Beachfront,Kitchen,Wifi,Dedicat...
# 1044   Beach access,Wifi,Dedicated workspace,Free par...
# 1138   Long-term stays allowed,Unavailable: Carbon mo...
# 3363   Kitchen,Wifi,Free parking on premises,Pets all...
# 3402   Garden view,Valley view,Kitchen,Wifi,Free park...
# 3465   Park view,Kitchen,Wifi,Dedicated workspace,Fre...
# 3564   Kitchen,Wifi,Free parking on premises,TV,Air c...
# 4660   City skyline view,Kitchen,Wifi,Free parking on...
# 5270   Wifi,Free parking on premises,Pets allowed,TV,...
# 5357   Wifi,Dedicated workspace,Free parking on premi...
# 5360   Garden view,Mountain view,Wifi – 28 Mbps,Dedic...
# 5902   Ocean view,Sea view,Wifi,Free on-street parkin...
# 6636   Garden view,Beach access – Beachfront,Kitchen,...
# 7037   Wifi,Free parking on premises,TV,Washing machi...
# 8250   Kitchen,Free parking on premises,Pool,Pets all...
# 10407  Kitchen,Wifi,Free parking on premises,Private ...
# 10851  Wifi,Dedicated workspace,Unavailable: Carbon m...
# 11729  Beach access,Kitchen,Wifi,Free parking on prem...
# 12777  Sea view,Harbour view,Beach access – Beachfron...
#
#                                             safety_rules  ...       country  \
# 726    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...  ...         India
# 833    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...  ...         India
# 835    󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...  ...         India
# 1044   󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...  ...     Sri Lanka
# 1138   󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...  ...      Thailand
# 3363   󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...  ...         Italy
# 3402   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...  ...         Italy
# 3465   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...  ...         Italy
# 3564   󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...  ...         Italy
# 4660   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...  ...   South Korea
# 5270   󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...  ...      Thailand
# 5357   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...  ...         India
# 5360   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...  ...         India
# 5902   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...  ...        Greece
# 6636   󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...  ...         India
# 7037   󹀁,Airbnb's COVID-19 safety practices apply,Car...  ...         Japan
# 8250   󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...  ...   South Korea
# 10407  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...  ...         India
# 10851  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...  ...   South Korea
# 11729  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...  ...         Egypt
# 12777  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...  ...   South Korea
#
#       bathrooms  beds guests  toiles  bedrooms  studios              checkin  \
# 726           2     1      4       0         1        0   10 00 am - 8 00 pm
# 833           1     2      4       0         2        0   12 00 pm - 2 00 pm
# 835           1     2      4       0         2        0             Flexible
# 1044          1     1      2       0         1        0             Flexible
# 1138          1     1      2       0         1        0                  NaN
# 3363          1     3      4       0         2        0    1 00 pm - 7 00 pm
# 3402          2     4      6       0         3        0        After 4 00 pm
# 3465          4     4      8       0         4        0    3 00 pm - 8 00 pm
# 3564          1     3      4       0         2        0    3 00 pm - 7 00 pm
# 4660          1     2      5       0         1        0        After 3 00 pm
# 5270          1     1      2       0         1        0       After 12 00 pm
# 5357          4     1      2       0         1        0        After 2 00 pm
# 5360          3     7     10       0         3        0       After 12 00 pm
# 5902          2     2      5       0         2        0        After 3 00 pm
# 6636          1     1      2       0         1        0             Flexible
# 7037          0     6      6       1         1        0   3 00 pm - 10 00 pm
# 8250          2     2      6       0         2        0   3 00 pm - 10 00 pm
# 10407         5     4      8       0         4        0        After 1 00 pm
# 10851         0     0      8       0         0        0        After 3 00 pm
# 11729         1     3      3       0         1        0             Flexible
# 12777         1     1     10       0         1        0        After 2 00 pm
#
#         checkout  clean_country
# 726      1 00 pm          India
# 833     12 00 pm          India
# 835     12 00 pm          India
# 1044    12 00 pm      Sri Lanka
# 1138         NaN       Thailand
# 3363    10 00 am          Italy
# 3402    10 00 am          Italy
# 3465    10 00 am          Italy
# 3564    10 00 am          Italy
# 4660    11 00 am    South Korea
# 5270    12 00 pm       Thailand
# 5357    12 00 pm          India
# 5360    10 00 am          India
# 5902    11 00 am         Greece
# 6636    10 00 am          India
# 7037    10 00 am          Japan
# 8250    11 00 am    South Korea
# 10407   11 00 am          India
# 10851        NaN    South Korea
# 11729   12 00 pm          Egypt
# 12777   11 00 am    South Korea
#
# [21 rows x 23 columns]

# %%
df['features']
# Out:
# 0                2 guests,2 bedrooms,1 bed,1 bathroom
# 1              4 guests,2 bedrooms,2 beds,2 bathrooms
# 2                4 guests,1 bedroom,3 beds,1 bathroom
# 3                4 guests,1 bedroom,2 beds,1 bathroom
# 4                 2 guests,1 bedroom,1 bed,1 bathroom
#                              ...
# 12800                            4 guests,8 bathrooms
# 12801       2 guests,1 bedroom,1 bed,Toilet with sink
# 12802    2 guests,1 bedroom,2 beds,1 private bathroom
# 12803        8 guests,2 bedrooms,4 beds,2.5 bathrooms
# 12804            5 guests,1 bedroom,2 beds,1 bathroom
# Name: features, Length: 12805, dtype: object

# %%
df
# Out:
#              id                                               name  rating  \
# 0      49849504                                     Perla bungalov    4.71
# 1      50891766  Authentic Beach Architect Sheltered Villa with...    0.00
# 2      50699164                                  cottages sataplia    4.85
# 3      49871422                        Sapanca Breathable Bungalow    5.00
# 4      51245886                                      Bungalov Ev 2    0.00
# ...         ...                                                ...     ...
# 12800  44697740            Brown Dome House No. 3, full of healing    4.94
# 12801  29975283       Bubble Hotel Ubud with Bathtub under the Sky    4.67
# 12802  32977697                                   Paradise Eco Hub    4.67
# 12803   8006146     WisDOME - Mentigi Bay Village - Gilis - Lombok    4.86
# 12804  40547903   Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]    4.85
#
#        reviews    host_name      host_id  \
# 0           64    Mehmetcan  357334205.0
# 1            0        Fatih  386223873.0
# 2           68       Giorgi  409690853.0
# 3           13        Melih  401873242.0
# 4            0  Arp Sapanca  414884116.0
# ...        ...          ...          ...
# 12800       16        Aidan  161552316.0
# 12801        6       Martha  118954227.0
# 12802        3        Silas  175214568.0
# 12803        7      Cempaka     718423.0
# 12804       13         Achy  246470880.0
#
#                                                  address  \
# 0                               Kartepe, Kocaeli, Turkey
# 1                                   Kaş, Antalya, Turkey
# 2                                       Imereti, Georgia
# 3                               Sapanca, Sakarya, Turkey
# 4                               Sapanca, Sakarya, Turkey
# ...                                                  ...
# 12800  Imhoe-myeon, Jindo, South Jeolla Province, Sou...
# 12801                                 Gianyar, Indonesia
# 12802                                     Kabale, Uganda
# 12803        Gunung Sari, Nusa Tenggara Barat, Indonesia
# 12804                              Uruma, Okinawa, Japan
#
#                                            features  \
# 0              2 guests,2 bedrooms,1 bed,1 bathroom
# 1            4 guests,2 bedrooms,2 beds,2 bathrooms
# 2              4 guests,1 bedroom,3 beds,1 bathroom
# 3              4 guests,1 bedroom,2 beds,1 bathroom
# 4               2 guests,1 bedroom,1 bed,1 bathroom
# ...                                             ...
# 12800                          4 guests,8 bathrooms
# 12801     2 guests,1 bedroom,1 bed,Toilet with sink
# 12802  2 guests,1 bedroom,2 beds,1 private bathroom
# 12803      8 guests,2 bedrooms,4 beds,2.5 bathrooms
# 12804          5 guests,1 bedroom,2 beds,1 bathroom
#
#                                                amenities  \
# 0      Mountain view,Valley view,Lake access,Kitchen,...
# 1      Kitchen,Wifi,Dedicated workspace,Free parking ...
# 2      Mountain view,Kitchen,Wifi,Dedicated workspace...
# 3      Mountain view,Valley view,Kitchen,Wifi,Free pa...
# 4      Kitchen,Wifi,Free parking on premises,TV,Air c...
# ...                                                  ...
# 12800  Kitchen,Wifi,Free parking on premises,Private ...
# 12801  Wifi,Free on-street parking,Air conditioning,G...
# 12802  Wifi,Breakfast,Long-term stays allowed,Unavail...
# 12803  Kitchen,Wifi,Dedicated workspace,Free parking ...
# 12804  Sea view,Beach access – Beachfront,Kitchen,Wif...
#
#                                             safety_rules  ...       country  \
# 0      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...  ...        Turkey
# 1      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...  ...        Turkey
# 2      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...  ...       Georgia
# 3      󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...  ...        Turkey
# 4      󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...  ...        Turkey
# ...                                                  ...  ...           ...
# 12800  󹀁,Airbnb's COVID-19 safety practices apply,󱠁,C...  ...   South Korea
# 12801  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...  ...     Indonesia
# 12802  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,N...  ...        Uganda
# 12803  󹀁,Airbnb's COVID-19 safety practices apply,󱠆,C...  ...     Indonesia
# 12804  󹀁,Airbnb's COVID-19 safety practices apply,󱠃,S...  ...         Japan
#
#       bathrooms  beds guests  toiles  bedrooms  studios              checkin  \
# 0             1     1      2       0         2        0             Flexible
# 1             2     2      4       0         2        0   4 00 pm - 11 00 pm
# 2             1     3      4       0         1        0        After 1 00 pm
# 3             1     2      4       0         1        0        After 2 00 pm
# 4             1     1      2       0         1        0        After 2 00 pm
# ...         ...   ...    ...     ...       ...      ...                  ...
# 12800         8     0      4       0         0        0   3 00 pm - 11 00 pm
# 12801         0     1      2       1         1        0   3 00 pm - 10 00 pm
# 12802         1     2      2       0         1        0        After 3 00 pm
# 12803         2     4      8       0         2        0             Flexible
# 12804         1     2      5       0         1        0        After 4 00 pm
#
#         checkout  clean_country
# 0       12 00 pm         Turkey
# 1       10 00 am         Turkey
# 2       12 00 pm        Georgia
# 3       12 00 pm         Turkey
# 4       12 00 pm         Turkey
# ...          ...            ...
# 12800   11 00 am    South Korea
# 12801   12 00 pm      Indonesia
# 12802        NaN         Uganda
# 12803   12 00 pm      Indonesia
# 12804   11 00 am          Japan
#
# [12805 rows x 23 columns]

# %%
country = 'Japan'

print(int(df[df['clean_country'] == country]['price'].min()))
print(int(df[df['clean_country'] == country]['price'].mean()))
print(int(df[df['clean_country'] == country]['price'].max()))
# Out:
# 1330
# 10416
# 64317

# %%
df = pd.read_csv('/content/datasets/Job Postings/jobs.csv.zip')

df
# Out:
#              job_id                                           job_role  \
# 0      7.012301e+10      Branch Banking - Calling For Women Candidates
# 1      6.012391e+10                       Product Owner Senior Manager
# 2      6.012391e+10  Employee Relations and Policies Associate Manager
# 3      6.012391e+10         Employee Relations and Policies Specialist
# 4      6.012301e+10                                  SAP BO Consultant
# ...             ...                                                ...
# 79142  6.012301e+10                           .Net Fullstack Developer
# 79143  1.122201e+10        Senior (BI) Business Intelligence Architect
# 79144  1.512220e+11                                  PowerBI Developer
# 79145  2.712220e+11                         Customer Service Associate
# 79146  2.112220e+11                   Senior Java BED ( PAN India)- KG
#
#                      company experience                     salary  \
# 0                  Hdfc Bank    1-6 Yrs              Not disclosed
# 1                  Accenture  11-15 Yrs              Not disclosed
# 2                  Accenture    3-7 Yrs              Not disclosed
# 3                  Accenture    3-7 Yrs              Not disclosed
# 4                   Mindtree    5-7 Yrs              Not disclosed
# ...                      ...        ...                        ...
# 79142             Citiustech    3-8 Yrs   7,00,000 - 17,00,000 PA.
# 79143  Hexaware Technologies  10-13 Yrs              Not disclosed
# 79144                     EY   5-10 Yrs              Not disclosed
# 79145          Tech Mahindra    0-2 Yrs    2,50,000 - 3,50,000 PA.
# 79146          Tech Mahindra   8-12 Yrs  25,00,000 - 27,50,000 PA.
#
#                                                 location  rating  \
# 0      Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...     4.0
# 1      Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1
# 2      Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1
# 3      Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1
# 4      Hybrid - Kolkata, Hyderabad/Secunderabad, Pune...     4.1
# ...                                                  ...     ...
# 79142  Hybrid - Pune, Bangalore/Bengaluru, Mumbai (Al...     4.0
# 79143  Hybrid - Pune, Chennai, Bangalore/Bengaluru, M...     3.7
# 79144                  Hybrid - Pune, Mumbai (All Areas)     3.8
# 79145  Temp. WFH - Noida, Kolkata, New Delhi, Hyderab...     3.7
# 79146  Temp. WFH - Noida, Kolkata, Hyderabad/Secunder...     3.7
#
#              reviews                                    resposibilities  \
# 0      39110 Reviews     Customer Service,Sales,Relationship Management
# 1      32129 Reviews  Product management,Market analysis,Change mana...
# 2      32129 Reviews  Business process,Change management,Team manage...
# 3      32129 Reviews  Business process,Change management,Team manage...
# 4       3759 Reviews  SAP BO,PL / SQL,Oracle SQL,SAP Business Object...
# ...              ...                                                ...
# 79142    742 Reviews  c#,.net core,javascript,Microservices,Angular,...
# 79143   3172 Reviews  Informatica Mdm,etl,business intelligence,Agil...
# 79144   6267 Reviews                            pagination,Power Bi,Dax
# 79145  21440 Reviews  Bengali,International BPO,BPO,Customer Service...
# 79146  21440 Reviews  Kafka,sql,spring boot,REST API,java,Lambda,Des...
#
#          posted_on                                           job_link  \
# 0        1 Day Ago  https://www.naukri.com/job-listings-branch-ban...
# 1        1 Day Ago  https://www.naukri.com/job-listings-product-ow...
# 2        1 Day Ago  https://www.naukri.com/job-listings-employee-r...
# 3        1 Day Ago  https://www.naukri.com/job-listings-employee-r...
# 4        1 Day Ago  https://www.naukri.com/job-listings-sap-bo-con...
# ...            ...                                                ...
# 79142   2 Days Ago  https://www.naukri.com/job-listings-net-fullst...
# 79143    1 Day Ago  https://www.naukri.com/job-listings-senior-bi-...
# 79144   2 Days Ago  https://www.naukri.com/job-listings-powerbi-de...
# 79145  10 Days Ago  https://www.naukri.com/job-listings-customer-s...
# 79146   3 Days Ago  https://www.naukri.com/job-listings-senior-jav...
#
#                                             company_link
# 0      https://www.naukri.com/hdfc-bank-jobs-careers-213
# 1      https://www.naukri.com/accenture-jobs-careers-...
# 2      https://www.naukri.com/accenture-jobs-careers-...
# 3      https://www.naukri.com/accenture-jobs-careers-...
# 4      https://www.naukri.com/mindtree-jobs-careers-3...
# ...                                                  ...
# 79142  https://www.naukri.com/citiustech-jobs-careers...
# 79143  https://www.naukri.com/hexaware-technologies-j...
# 79144        https://www.naukri.com/ey-jobs-careers-9156
# 79145  https://www.naukri.com/tech-mahindra-jobs-care...
# 79146  https://www.naukri.com/born-commerce-jobs-care...
#
# [79147 rows x 12 columns]

# %%
df['company'].nunique()
# Out:
# 15313
